# %% [markdown]
# # Información:
# * ## Katia Arévalo
# * ## kathimi@hotmail.com

# %% [markdown]
# # Preguntas

# %% [markdown]
# # Pregunta 1.
# ## Suponga que tiene una lista [1, 2, 3, 2, 1] y desea crear una nueva lista sin números dobles, después de resolver este problema, intente reescribirla como una sola línea.
# #### (Un "one liner" en programación, es un programa existente de una sola línea. Si no logras escribir una sola línea, no te preocupes, el código "one liner" es a menudo difícil de leer y, como hemos aprendido esta semana: los lenguajes de programación están destinados a ser legibles para las personas. Así que no te preocupes si estás usando demasiado código para resolver un problema, debes preguntarte: ¿yo o alguien más entenderá esto dentro de 3 años?)

# %%
my_set = {1, 2, 3, 2, 1}   ##Set: único, inmutable y no mantiene el orden de los elementos dentro de sí.##
print(my_set)
# Out:
# {1, 2, 3}

# %% [markdown]
# # Pregunta 2.
# ## "Slicing" puede tener 3 parámetros, inicio, final y paso. Sin embargo, a menudo escribirá o leerá operaciones de corte con menos de 3 parámetros. En esta pregunta, debe volver a escribir todos los ejemplos en operaciones de corte con 3 parámetros. Después de haberlas reescrito, verifique si sus respuestas dan los mismos resultados

# %%
string_1 = 'abcde'
print(string_1[1:3])
print(string_1[-3:-2])

print(string_1[:3])
print(string_1[3:])
print(string_1[:])

print(string_1[-2:])
print(string_1[:-2])

print(string_1[::])
print(string_1[::-1])

print(string_1[:3:1])
print(string_1[:3:-1])

print(string_1[1::])
print(string_1[:1:-1])
# Out:
# bc
# c
# abc
# de
# abcde
# de
# abc
# abcde
# edcba
# abc
# e
# bcde
# edc

# %% [markdown]
# ### Reescribiendo

# %%
string_1 = "abcde"
print(string_1[1:3:1])
print(string_1[2:3:1])
print(string_1[:3:1])
print(string_1[3::1])
print(string_1[::1])
print(string_1[::-1])
print(string_1[:3:1])
print(string_1[5:3:-1])
print(string_1[1:5:1])
print(string_1[-1:-4:-1])
# Out:
# bc
# c
# abc
# de
# abcde
# edcba
# abc
# e
# bcde
# edc

# %% [markdown]
# # Pregunta 3.
# * ## Hemos construido un diccionario que se puede usar para encontrar el resultado si dos booleanos están conectados con el operador.
# * ## Reescribe este diccionario para encontrar el resultado si dos booleanos están conectados con el operador o Python no tiene un operador XOR, busque en Internet lo que se supone que debe hacer el operador XOR y cree un diccionario que proporcione el resultado de una operación XOR

# %%
age = 40
blood_type = 'A'
my_and = {(True, True): True, (True, False): False, (False, True): False, (False, False): False }
print(my_and[age < 70, blood_type == 'B'])
# Out:
# False

# %% [markdown]
# ## Reescribiendo

# %%
age = 40
blood_type = 'A'
my_and = {(True, True): True, (True, False): True, (False, True): True, (False, False): False }
print(my_and[age < 70, blood_type == 'B'])
# Out:
# True

# %% [markdown]
# # Pregunta 4.
# ## "Las listas pueden contener listas y así formar tablas de múltiples dimensiones" se les mostro una secuencia ganadora en tres en raya. Como es muy importante para el análisis de datos y la visualización de datos que se sienta cómodo trabajando con tablas poli-dimensionales, le pedimos que reescriba la secuencia con un segundo jugador más inteligente (o un jugador que aprendió el juego de memoria) donde el juego termina en un empate.

# %%
tic_tac_toe_board = [[' ', ' ', ' '], [' ', ' ', ' '], [' ', ' ', ' ']]
print(tic_tac_toe_board[0]) 
print(tic_tac_toe_board[1]) 
print(tic_tac_toe_board[2])
print() 
tic_tac_toe_board[1][1] = 'X'
print(tic_tac_toe_board[0]) 
print(tic_tac_toe_board[1]) 
print(tic_tac_toe_board[2])
print() 
tic_tac_toe_board[0][2] = 'O'
print(tic_tac_toe_board[0]) 
print(tic_tac_toe_board[1]) 
print(tic_tac_toe_board[2])
print()
tic_tac_toe_board[1][2] = 'X'
print(tic_tac_toe_board[0]) 
print(tic_tac_toe_board[1]) 
print(tic_tac_toe_board[2])
print()
tic_tac_toe_board[1][0] = 'O'
print(tic_tac_toe_board[0]) 
print(tic_tac_toe_board[1]) 
print(tic_tac_toe_board[2])
print()
tic_tac_toe_board[0][0] = 'X'
print(tic_tac_toe_board[0]) 
print(tic_tac_toe_board[1]) 
print(tic_tac_toe_board[2])
print()# And the next move X wins independent what player O plays
tic_tac_toe_board[2][2] = 'O'
print(tic_tac_toe_board[0]) 
print(tic_tac_toe_board[1]) 
print(tic_tac_toe_board[2])
print()
tic_tac_toe_board[2][1] = 'X'
print(tic_tac_toe_board[0]) 
print(tic_tac_toe_board[1]) 
print(tic_tac_toe_board[2])
print()
tic_tac_toe_board[0][1] = 'O'
print(tic_tac_toe_board[0]) 
print(tic_tac_toe_board[1]) 
print(tic_tac_toe_board[2])
print()
# Out:
# [' ', ' ', ' ']
# [' ', ' ', ' ']
# [' ', ' ', ' ']
#
# [' ', ' ', ' ']
# [' ', 'X', ' ']
# [' ', ' ', ' ']
#
# [' ', ' ', 'O']
# [' ', 'X', ' ']
# [' ', ' ', ' ']
#
# [' ', ' ', 'O']
# [' ', 'X', 'X']
# [' ', ' ', ' ']
#
# [' ', ' ', 'O']
# ['O', 'X', 'X']
# [' ', ' ', ' ']
#
# ['X', ' ', 'O']
# ['O', 'X', 'X']
# [' ', ' ', ' ']
#
# ['X', ' ', 'O']
# ['O', 'X', 'X']
# [' ', ' ', 'O']
#
# ['X', ' ', 'O']
# ['O', 'X', 'X']
# [' ', 'X', 'O']
#
# ['X', 'O', 'O']
# ['O', 'X', 'X']
# [' ', 'X', 'O']

# %% [markdown]
# # Pregunta 5.
# ## Ejecute el siguiente programa, vea si puede encontrar algo extraño y explique el resultado usando su conocimiento de recolección de basura.

# %% [markdown]
# ### En la pregunta cinco, hay un error. El "id" de la primera y tercera lista son iguales, para corregirlo se agrega en la siguiente línea la función "del list_5" para que el objeto sea elgible para la recolección de basura.

# %%
list_5 = [1, 2, 3]
print(f"The value of the list refered to by list_5 is {list_5} and its address is {id(list_5)}")
del list_5
list_5 = [1 , 1, 3]
print(f"The value of the list refered to by list_5 is {list_5} and its address is {id(list_5)}")
list_5 = [1, 1, 4]
print(f"The value of the list refered to by list_5 is {list_5} and its address is {id(list_5)}")
# Out:
# The value of the list refered to by list_5 is [1, 2, 3] and its address is 140166015320864
# The value of the list refered to by list_5 is [1, 1, 3] and its address is 140166015690784
# The value of the list refered to by list_5 is [1, 1, 4] and its address is 140166140934896

# %% [markdown]
# # Pregunta 6.
# ## Las cadenas son inmutables, pero ¿por qué funciona lo siguiente? ¿Claramente cambiamos el valor de la cadena llamada string_1? ¿Qué afirmaciones agregaría para aclarar lo que ha sucedido? usar id.

# %% [markdown]
# ### En la pregunta seis, se asigna una cadena a una variable o lista, por lo que al correr la segunda línea va a mostrar como resultado "text_1", y al correr la tercera y cuarta línea, la variable va a tomar el nuevo valor "text_2". Al usar el identificador observamos que es único para cada lista.
#
# * ### Cadena: inmutable
# * ### Lista: mutable

# %%
string_1 = "text 1"
print(id(string_1))
string_1 = "text 2"
print(id(string_1))
# Out:
# 140166015810608
# 140166015810480
